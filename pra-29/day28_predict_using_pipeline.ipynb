# %%
import pickle
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
import pandas as pd

# %%
test_input_df = pd.DataFrame([{
    'Pclass': 2,
    'Sex': 'male',
    'Age': 31.0,
    'SibSp': 0,
    'Parch': 0,
    'Fare': 10.5,
    'Embarked': 'S'
}])

# %%
pipe.predict(test_input_df)
# Out:
# array([0])
